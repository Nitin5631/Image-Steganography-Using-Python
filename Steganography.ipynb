# %%
#import all the required libraries
import cv2
import pandas as pd
import numpy as np
import types
from matplotlib import pyplot as plt

# %%
def messageToBinary(message):
  if type(message) == str:
    return ''.join([ format(ord(i), "08b") for i in message ])
  elif type(message) == bytes or type(message) == np.ndarray:
    return [ format(i, "08b") for i in message ]
  elif type(message) == int or type(message) == np.uint8:
    return format(message, "08b")
  else:
    raise TypeError("Input type not supported")

# %%
# Function to hide the secret message into the image

def hideData(image, secret_message):

  # calculate the maximum bytes to encode
  n_bytes = image.shape[0] * image.shape[1] * 3 // 8
  print("Maximum bytes to encode:", n_bytes)

  #Check if the number of bytes to encode is less than the maximum bytes in the image
  if len(secret_message) > n_bytes:
      raise ValueError("Error encountered insufficient bytes, need bigger image or less data !!")
  
  secret_message += "#####" # you can use any string as the delimeter

  data_index = 0
  # convert input data to binary format using messageToBinary() fucntion
  binary_secret_msg = messageToBinary(secret_message)

  data_len = len(binary_secret_msg) #Find the length of data that needs to be hidden
  for values in image:
      for pixel in values:
          # convert RGB values to binary format
          r, g, b = messageToBinary(pixel)
          # modify the least significant bit only if there is still data to store
          if data_index < data_len:
              # hide the data into least significant bit of red pixel
              pixel[0] = int(r[:-1] + binary_secret_msg[data_index], 2)
              data_index += 1
          if data_index < data_len:
              # hide the data into least significant bit of green pixel
              pixel[1] = int(g[:-1] + binary_secret_msg[data_index], 2)
              data_index += 1
          if data_index < data_len:
              # hide the data into least significant bit of  blue pixel
              pixel[2] = int(b[:-1] + binary_secret_msg[data_index], 2)
              data_index += 1
          # if data is encoded, just break out of the loop
          if data_index >= data_len:
              break

  return image

# %%
def showData(image):

  binary_data = ""
  for values in image:
      for pixel in values:
          r, g, b = messageToBinary(pixel) #convert the red,green and blue values into binary format
          binary_data += r[-1] #extracting data from the least significant bit of red pixel
          binary_data += g[-1] #extracting data from the least significant bit of red pixel
          binary_data += b[-1] #extracting data from the least significant bit of red pixel
  # split by 8-bits
  all_bytes = [ binary_data[i: i+8] for i in range(0, len(binary_data), 8) ]
  # convert from bits to characters
  decoded_data = ""
  for byte in all_bytes:
      decoded_data += chr(int(byte, 2))
      if decoded_data[-5:] == "#####": #check if we have reached the delimeter which is "#####"
          break
  #print(decoded_data)
  return decoded_data[:-5] #remove the delimeter to show the original hidden message

# %%
# Encode data into image 
def encode_text(): 
  image_name = input("Enter image name(with extension): ") 
  image = cv2.imread(image_name) # Read the input image using OpenCV-Python.
  #It is a library of Python bindings designed to solve computer vision problems. 
  
  #details of the image
  print("The shape of the image is: ",image.shape) #check the shape of image to calculate the number of bytes in it
  print("The original image is as shown below: ")
  resized_image = cv2.resize(image, (500, 500)) #resize the image as per your requirement
  plt.imshow(resized_image)
  plt.show()  #display the image
  
      
  data = input("Enter data to be encoded : ") 
  if (len(data) == 0): 
    raise ValueError('Data is empty')
  
  filename = input("Enter the name of new encoded image(with extension): ")
  encoded_image = hideData(image, data) # call the hideData function to hide the secret message into the selected image
  cv2.imwrite(filename, encoded_image)

# %%
# Decode the data in the image 
def decode_text():
  # read the image that contains the hidden image
  image_name = input("Enter the name of the steganographed image that you want to decode (with extension) :") 
  image = cv2.imread(image_name) #read the image using cv2.imread() 

  print("The Steganographed image is as shown below: ")
  resized_image = cv2.resize(image, (500, 500))  #resize the original image as per your requirement
  plt.imshow(resized_image)
  plt.show() #display the Steganographed image 
  text = showData(image)
  return text

# %%
# Image Steganography         
def Steganography(): 
    a = input("Image Steganography \n 1. Encode the data \n 2. Decode the data \n Your input is: ")
    userinput = int(a)
    if (userinput == 1):
      print("\nEncoding....")
      encode_text() 
          
    elif (userinput == 2):
      print("\nDecoding....") 
      print("Decoded message is " + decode_text()) 
    else: 
        raise Exception("Enter correct input") 
          
Steganography() #encode image
# Out:
# Image Steganography
#  1. Encode the data
#  2. Decode the data
#  Your input is: 1
#
# Encoding....
# Enter image name(with extension): image.jpg
# The shape of the image is:  (780, 651, 3)
# The original image is as shown below:
# Enter data to be encoded : hlo
# Enter the name of new encoded image(with extension): image1.jpg
# Maximum bytes to encode: 190417

# %%
Steganography() #encode image
# Out:
# Image Steganography
#  1. Encode the data
#  2. Decode the data
#  Your input is: 2
#
# Decoding....
# Enter the name of the steganographed image that you want to decode (with extension) :image1.jpg
# The Steganographed image is as shown below:
# aÛaÿÿüÀá¶ãs# ÿÀ?À?ÿÿÀ?ÿÿÀøàÀ?ð?ÀÿøàøÀàüp?àø~;¸äpÇã?ÿñÇÇ~ã	$R	FqþLÜÿààÿÿàÿÿàÇüp?àøÿÿÿÿÿÿüpÇüüÀþ8ðÀüp?â6ÜnGøþ8ãù#n8äÇ#	1¶8A$¤øÀïÇüpÀðÿÿðÿÿðãþ8ðÇüÀðÿÿþ8ãþãþàÿøàøàøÿð¶äÇ8ärHà7¢a·m$I68ãGÿÿÀàøÿÿøÿÿøñÿøãþàøÿÿñÿ¶ÛnFëlðÿüþüþÿñøÿÿÀI#ø¶ã9$|Ç8H¨0EÄ #m³ÀðüÿÿüøÿüñÿðÿÿÿüÿÿøÿÛm¶äm¸øÇþÿþÿÿøÿÆä9?[pæ8s['ÙÁØè$À#rHæüpø~ÿÿþÿÿþüÇþøÿø~ÿÿðÿÿÿÿÿãÿÿ?ãÿÿ~ü~8ÆÛnIøÿþÿñÿÿÿðãþàÿÿÿãðÛr8Ücø$8Ç8o¸
# Ql[H¿Îd±äM¶à~8ÿðñøÿÿÀãÿÿÿÿÿÿüqÇÇÿð8ÆäHÜrpñøÿñÿÿà~8øÿÿÿÿÇp?î9nOÿà~ü<p$­°ñãÂ©.#ce@ù¾!bI&Ûp8ãÿ?Àqÿÿ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÇøÿÀãñÿüp~ÈÜrI?ÇãÇãð8üqøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÿp8ÿ7ü~?Ãû;ü	àáS¤C»Ä[(L$IÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀøÿÿÿÿÿÿÿÿÿÿÿÀÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿãþÇ8üpI#Is8þ8øããþð?ÿ8ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð8?ü¸äsÿÀîpÞä.óÄVNpÑñÂSÞI$àp?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿàÿÿÿÿüÿÿÿÿÿÿÿÿÿÿàÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþ?ÿÇþÿÛm¶ÜnH?Çð8ÿø?ãÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÿþ8þ6Ûm¸?ãÿÀü6¿bð^ûìn;Uð»ØçË°ä@?ãÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿü?ÿÿÿÿÿÿÿÿÿÿðÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÿñøpÀà~8nHãr8Û~ã?àøøàqÀÿþ?àÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÇãðÛÆäÀð
# ÈÜo¿
# mF<`*þmÉ?ÿù'm¹$ÑýoÄF -àåãÿÀÿðãÿÇÿãÿÿÿàÿÿ8üøüøãÿÇÇðà7$Ç#ÿ8qÇü8ÿð?ÿpãþ?þ?üp?üÿÄm¸ÛÈäÇ#è)¹'òIy8oI$`ü¶Ühþ·ã#ë|<Ë`pññÿãÿqÿã?ÿñÀ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ?ÿÿÀ?ÿÿÀ?ÿÿÿÿÿÀ?ÿÿÿÿÿÿÿÿÀ?ÿÿÿÿÿÿÿÿÀ?üÿÀãÀãÿÀðãÿpã?þ8ÿÀÀüpàpÿøÀ?ÿðqÇãÿÇ?àÿÿÿÿÿÿÿ$m¹m¹#m¶à@VÓÁÿñÃ9·m¶ÛN´[ðõi@
# ¤øü	ð?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿàøÿñÿÿÿÿÿÿÿÿÿÀÿøàÿÿÿÿÿÿÿÿÿÿÿÿÿÿàÿÿàÿÿÿÿÿàÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿàÿÿÿÿÿÿÿÿàñøqÇÿð8pü8ÿ8?qÇü~8ãð8ÿøãþüü?ÿÿÀÇÿþüÀqÿñøþ?ÿÿÿàðÌrI$I#qÆÛ\oùàqÇÿÏ@Ôù$òIÚ?­øÚÁìÌ4Càp9ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð8øÿÿÿÿÿÿÿÿÿàÿüpÿÿÿÿÿÿÿÿÿÿÿÿÿÿðÿÿðÿÿÿÿÿðÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðÿÿÿÿÿðÿüpàqøÿ?àÇ8ãþ8àp?ÿþ?à~?üÿãñÿ8àøãþü~?ÿøqÿü?àqÿüÿÿðÿ-¶änFÛnG$ÂÅu?® 	"I+ÿÿù#ÿÖüMÆ8°à±ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿø?üÿÿÿÿÿÿÿÿðÿþ8ÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÿÿøÿÿøÿÿÿÿÿøÿÿÿÿÿÿÿÿøÿÿÿÿÿøüøãÿø?àÇÀãqøüÇãÀ~?ÿÿüÇÇÿÿÇpü~8ÿã?8qÿÿÿÿÿÿøà6Ü·$HÜqÆÆ4Ý¿6âà~Z;T¿ÿümøÿø <èyÛ¢PÇðàü?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿüÿþ?ÿÿÿÿÿÿÿÿøÿÿÿÿüqøÿ8pÿãñÿãñÇqÇÿãþ8øÀñÇà8øÿÇpã?ãÿÿüqÿüpÿü?üpr9#ÆÛFä;ÑÜÎÇWùHÜÛmµ¶ÿüÇüÚW§/@¨Çoøü?üÿÿÿÿÿþÿÿþÿÿþÀàÿÿþÿÿÇàqøÿÿÀüøãÇÿÿàp?ãÿqÿþüÇãñøãÿàÇøbÿãþÿÿàøåÆãÆÜlã ØV¸á$¤ç¾â(Ûsþ?ãþí«ky¬@ÜCÂ8ÿþÿàÇÿÿÿÇü?ü?ãÿÿÿÿÿÿVÛÆÜ?Çã8ü~~?ÿà~ÀãÀ?àqøàqøÀÿþ?rG#Häã{8äÿÀÀàÿÿñÿä¹l	Â:@M(h¾Ô$ÿxÛ$í$ÿí·m°àFÒÿÿÿÿÿÿÀÿÿÿ~?ü~üÀÿÿÿÿÿÿÿÿÿãÿÿ~~ñÿÿ?ü;d®9#r8àÇ~àÇãÿø?ÿ??Çü~8ÿÿÀÇà9¶ämÀòfÛÍÿÀÿñÿÿãÿÇü9q·$¶DàÄåp3ø¨!jMþr·$àm¶ÍÆ?ÿ¶Û6Øüä I#iÀÿÿà?þ?~?à?ÿñÀ?À?øÿÿÀ?ãÝvÇ$ÈÿàÿñÿüÇþ?àpÿÿÀÿ?ã8àqÇüÇÿ8üÀà#n7Hÿôiàp?þ8ãÿáqÇ$m¹"FÈh6Íþ#Pµ)?I¹CÿÿM¶6ÀÿÿÚIÇm¶>|´ñÀÿðÿ?ð?ÿÿøàÿÿààüÿàÿøYq¶ã|8~?ÿÿÿãð?p?üÀð?8?ñø?ÿÀã?à~G$qÇ#n7#ÿp8üøìÇ#ÈänÜÁûÌ?ÇnG±ÔT¤ ?á¶Ù;FÛ`pñ%¶Ûp~H@øàøÇÿÀøÿÿüpÀðÀþ?ÿðø#nFÜrOÿÀã8ÿðÿþ8ããþ8àqÇãÀÿ?Àqÿãñÿàÿ÷#7#mÎÞÍ°Çãþ?ÿÇàÛqÉ#¶wm+c±Çí«jV®¶OÂJßÀFÙ$Ûñøymª¤I	a,?$¾?üãÿÇàÇüÿÿþ8àøàÿÿøÿÿøÅ6Û¹ ÿqÿñÀñÀñÿààÿðqÿÿÿÇãÇü~ÿÀÿø98çã¹ üø8ÿùÇ$·$ÄI3F­JÀ
# É#nHàüqãÿÿüqÀãÇLGôI$àÀÀãþ?ÿþÿ?HÛmÇÇÇàÀø?Àü~?üÀ?àpãøüøàÀÇà8¸äGn8ä|ÆmqÀ·#ÈÛmÄoÀoò>=¼Hãsú­UIä88íÉÿÿÿà?àÜ|äøÿÿñÿ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ?ÿÿÿü?ü~$n9$mÈÀãÇÿÿàÇÿÇà~?ÿÀp88üp8ÿñÿqÿñÇãðqãqÇ$¶ämÈÇÿÿÿÿÿÿÿÿÿÿÀüqÜrn7á°Á$xá¹ýVª­ITÀÿøÿ#?À$8ãÿßsè
# ãnI$NOÀVªlm
# ·øÞ¯eùxÏÿø~ÿÿÿÿÿþÇÿþÿÿÿÇÿÿÿã?mØërCãI$Gm¸dÈÜÿøÿøÿÿÿÿÿÿÿÿÿü~8àÇÇÆÜm¶Ûm¶Ûm¶Ûà?ñÀüqÇqÀãøqøà?øà~8ÿð?ü?ÿ8qÿã??ãÿ?ÿÿÿü9]Éªlà~­¦çm¶ÛI$I$I$I$I<V
# Ü3A`ñÇÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ~?àÿÿÿÿÿÿÿÿ?þþ Qµ-	G
# ð;.ãüpä·ð	;üoújÐN}$C¸ÛãcÇàÿÿüÀãÀîIm¶ÛÇ$I$¶ÛrI$¸Üqø8~àp?ÿÀãÿàÿñÇ~à?ÿÿÿÿÿÿÿÿü~8ü~8üøÿÿÇ?øÿÿÿÿÿÿÿÿÿàÿÿÿà¶Ûc6?ÿ$Î?QEÇßðÿÀÿÿÿÿÿÿÿÿàøÿÿàøðBËÿm%ÃpHørAÿ¿ø
# ±ÿà~?üøà?ÿ?ÿÿÀÿÿüÿÇðn8ãqÉmÉ$¶ÜHÜY8ÿÿüÀ?þ8ÿÿÿøã??üÀüøü?àÀÿÿÿÿÿÿø8ð?ÿÿÀ8ãÿÇãÿÿð?À1#`ü:6
# ?ñøÿÿþ8øøà~ñÇàøãþà8ÿÿÇqÇÿÿÿÿñÀ~?üÀÿIÃ|ÄASo¯Ýg£m¶ÛqÈçà7³ïÀâög|b<Ôþ8ãÿÿñøüÿÿÿÿÿ?ü~8~þþÿÿ?ÿÿöìwd0À$I´y$üqÿã?ÿÿÿÿÿÿÿð?ÿÿÇÿÀÿÀp8ãðàp8ãð?þüÿ~8ÿ?ÿÿøÿÀ8þ8ÿÿÿÿäáÀá¸b²-°uM)Qñä¸ÜqÉÜ?ÆÚHÛÈöæ;ÿøqÀþÿ8ÿÿÀ?ÿÿÀü~8ü~?ÿÿÿÿ~ÙÃ²x;·ÿàÿÿà$Ð	þzMÀ~ÿÿÿÿÿÿÿÿÿÿþ?ÿðÿÿÿÿþ8ÿÿÿþ8üqøqøqÿ?üøãÿÿàÿÿÿÇàÿÿÿÿÿÿÿÿàpã?ÿÿÿñðçàq$2¨ÒDÑ´P4'¸Ü·MÁtöÛt^5cþ#øà8ü?øãÿÇàÿÿàÿÿÿÿÿàüÿàÿÿÿÿÀÇg#ä?äÿÿðHÎcÙÿ?ÿÿÿÿÿÿÿÿÿÿÀðøÿÿþàøÿÿ~8üÀã8ãñÇàqÀüqÿàÿÿðüÿÿÿÿÿðÿãþãÿÿøÿppqÈ*2ûs
# ³sðãàãñÇü~?àÿÿü~?ÿüðÿðÿðÿÿøÿÿþ?ãÿdÞCbbÿ°ÿÿþÛI]©'ãÿÿÿÿÿÿÿÿÿÿø~8à~þ?ã~?Ç8àøþÿþüqÿÿÿÀðÿÿÿÿÿÿÿÿþüqøà~àññÀòHE`ù>6m7#s;í¸ämÆ.ÿ¡Ê_ñsGÀàÿ?àp~?üpÿÿþÿÿþÇÿÇøøøÿüÿÿÇÆÜ
# ¶Ûm¶Û!Î'ÀNÜÇÿÿÿü?ÿÿÿü??ÿøÿøüqÀü?àpøã?ÿÿÿÿñÀÿÇÿÿÿü?à?7$Û¸ÿ8ñ8r98ä·µ)ÏÖM°èÿãð8àøÀÀüÀÿÿÿÿÿÿÿÿÿÿÿÿÿñøàÿÿÿÿÿÿÿÿÿÿþÿÿÿÿÿÿÿÿÿÿãÇá7eìÛm¶Ûmç¸BD8ÿÿþÿÿÿþ8ÇàÇqÇ~ÿÇüqÿ8à8à~à?à~8ÿÇãÿÇàÿÿþñÿàqÇãm«½Àþ9$Èäú¤þÍ&ÙÉ~p?üÿÀp?þ?àÿÿÿÿÿÿ?øüÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ?ÿñÀ8ÿþãåÿ=¶ßÿÿÿÿÿÿÿÿÿs¹Çx,Gÿÿÿÿÿÿÿÿøü~8p?ÿÀ?øøü?ÿqÿÿÀÿþ8üpp?ÿÿÿÿÀ?ÿÿÀ?ÿÿÿÇã8ãÿÇ¹-ÏÌrÿðãÿÜm¹r9~ôd¾lq%Ïåø_ã?~8üÿð?ÿÿÿÿÿÿÿÿÿÿÿÀ?ÿÿÿÿÿÿÿÇãÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ?ÿ?ÿÿÿÿÿÿÿÿÀÿøàÿÀíÎ	ÀþÛoÿÿÿÿÿÿàm¿ãÇõ,ÿÿÿÿÿÿÿÿüqÇÿøÿÿÿÿÿàøøÿÿÀð?ÿÇàÿ8ÿøÿñÇÇÀÿÿàÿÿàÿÿÿÿøÿÿÿàÿ8Û\MAQàqÀüÀ9qÆäOÕÎü n*IàÿÿãÀà8p8øÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿà~?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿàÿÀÿÿÿÿÿÿÿÿàÿüpøã	Yþ;ÿÿÿÿÿÿÿÿðÅpæÿÿÿÿÀÿÿÿÿÀñÿàÿÿÿÿÿðà~Àþ8àp8ü8ü8ÿÇp?üqÇüð?þüÿÿðÿÿðÿÿÿÀÿÇüÿÿþãÿÀÿ ðh¬èð8qøÜ8ä³ Ûj*É](?»¿ÑV?ÿÿøãÿþÿÇüÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþ?üÿüÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðÿàÿÿÿÿÿÿÿÿðÿþ8üÇâ["Gûÿÿû
# µËôí«×|Ç~øàøÿÿÿÿÿÿþÇÇüÿÿþÿüÿhw?öu[@6Ãàøþp?þ?ÿñÀà~ü~8ãÿÀãðàqÿÿðøãÿã~ÿÿÿÿÆ«:f5	ÀÇÆÜ9  pÁ¶ÀÄ\]9äñÇ8ÿÿÿãþàqÇÿÿÿ´rLãÍ%_áÖú¢ø8?ÿ?ã?ãÀñÇ8ãþ8ñÀàü8qø~ÿÿ8ÿâÄÆMQ0àà7qÈÜoñÿÞ
# ¶È·Þc$òi Àøþ?ãñÀ?ÿÿÿÿÿÀ?ÿÿÿÿÿÿÿÿÿÀ8ãÿÿÿÀ?ÿÿÿÿÿÿÀÿÿÿÿÿÿÿÿÿÿÿÿÿÀøÿÇÿÿÿí¶Ûm¶Ûsÿÿm¶NíÛ$î0#þ8ÿÿÿàÿÿÿÿÿÿüqÀþ8àH
# gÕØôÑÅ£Ü8ÛI$ÿ$ÿùÿÿÿÿÿÿÿÿÿÿøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðÿÿÿÿÿÿü?ÿÿÿü?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿpþ?üqÀãÇÿÀãµ#?©
# qÎ?"ªß~»ÄÇû{Áír6I$8þ88ü?øþ?ÿÿü~ñÿãÿÿÿÿÿÿÿÿÿÌûý<H0<qÇÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ8üÿÿÿÿÿÿÿÿþÿÿÿþÿÿÿÿÿÿÿÿÿÿÿÿ?ÿÿÀ?ÿÿÀ8ð?ÿþ?þ8ü~üÜ¶ì¨ÃF ãÜJ+D{Ýß§¹$ÃoÀÀøÿðàpüÿÀÿÿÿ?ÿÿÀÿÿÿÿÿÿÿÿÿÀ5bZQ¹øî8ãÀ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀÿÀ?ÿÿÿÿÿÀ?ÿÿÿÿÿÀ?ÿÿÀ8ÿÀ?ÿÿÀ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀÿÿàÿÿàqÀñÿp8ÿÿÿÿÿüqÇø
# |n7ÉñÀþ[I&k'ÿüðãþøüÿðüÿà~àp?ÿÿü;ÒqÿCp8sÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿð?ÿÿÿüÿÿüÿÿüÿÿü8üðÿÿÿÿðüÿÿüÿÿþÇøÿqÀàq¥·áX£7ÙÁ+ð
# ã?^ÀÀÿãñÿÿÇÿøp~8ÿÿÿ?üÿÇüÿÿÿû`6ÜÄ=­ËÇÌ8~ÿÿÿÿÿþüÿÿÿÀñÇü~ÿÿÿÿÿÿÿÿþÿÿÿÇÿÿÿÿÿÿÿÿÿÿþ?ðÿÿþÿÿþÿÿÿÿÿÿüÿÿÿÿÿÿÿÿþqÿÿøü?ÿÀÀ<Æ©ýDµ ¶m¢ÉrG$n3ÏÏ²Ü?}õ{mîqøÿøÇÿþ8¶ÜG$à~?ü~?øñønG[qÈÜþ86ÛüqÇÿþ8ðà~ÿÿÀÀÿÿü~øüÿÿÿÿÿøãø&L§OôæÔú©ç#qÈämÏ#Q`Åý'â~8ÀñÿãÇà8[6Ü~ÿþ8ãÀüÿüGÆÜqÿÿÀü~8àÿÿÿÿÿÿÿÿ?ÿp?ñÿÿàüÇ?Àð?ÿÿÿÿÿøàpàpÀw¬Ø3o$Ë6Û8àõÁ¿sNÌ}ÿÇãÿÿøàÿãÌrGmÉqÇãøãÿàÉ#m¸ÿñÇÿÿÿÿÿÿÿÿÿÀãÿÇ8Àÿðÿðÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðàÿÿÿÿÿÿÿÿÿÿüÿÿÿÿÿÿÿü~üÿüÚµ8n~ÝîrmÇîIrIpÅ@hèXþÛã8qÇãÿÿãÀ6ä¹?ãð?ñÀàqøñÉ$¹$ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿñÇàÿÿÿÿÿÿÿÿàÿþ8ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿüÀÿð?àøÿÿÿÿÿÿÿÿÿÿÿÿÿÿàÿÿÿÿÿÿÿÿÿÿÿàÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿãñÿÿÿÿÿÿÿÿÿÿÀðÿÿÿÿÿðüqÀ
# ízdy?]yøÎü$mÉ¶Å"¬Ð9ú;ÂÀ?øÀ?àÿüwÆänOøøüÿãI#r1ÿüÿÿÿÿÿÿÿÿÿÿÿÿÿÿñÀàÀÿÿÿÿÿÿÿÿÿøðãÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþà~ÿ?üÿÿÿÿÿÿÿÿÿÿÿÿÿÿðÿÿÿÿÿÿÿÿÿÿÿðÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøüp8qÇÿÿÿÿÿÿÿÿÿàÿþ8ÿð9zÏf-e´Ï´u»6än6àg>©
# ÇrHÜ¹q¸ÛFãü~ÿÿÿü?à?üpÀü~8ÿÿÿÀãþ?ü?qÿãþÿÀÿãñÇã88¤I>sÚ¤PwÂ\m·'û¼Iû·:D?ãþ8ÿÇpàG$m¶ã6Ûm·$p8ÿÿ~ÿÀ8ãÿñÀÿÿÿqÇ~ÿÀÿÀ?àø~?ÿÀÿã¶'È°d,BL01ÿqíôÅùÉÊùl$ü~ÿãÀ8r6ä7$Çn9à?ÿÿÀ?Çãÿÿàp8?àqÀ?ÿÿÀ8ÿÇÀ?Àÿÿÿÿÿÿÿÿÿÿÿÿÿÿàÿÿÿÿÿà?þÿÿÿÿÿàþ?~üÀÀg~J°}B¢é$³¦ãm¶´Tè
# íÓoï
# Ijì[¸à~?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ8üÇüp?ÿñøÿÿøÇÿÿÿÿÿÿÿÿÿÿÿÿÿÿü~8àÇÿÿü~8püqÇÿÿÿÿÿÿü7·8tñ¡ÕES¿pO;IlÛ¿¿VÃàÝ¥éRÀð?ÿÿüÿÿüÿÿüpñÀãþãð?üÇÿÿÿÿÿÿÿÿÿÿÿÿÿÿþ8~àÿÿÿÀÿÇüÿãÿÿþÛGÀÿ¼ó2É½¢ÿ ÛÊ
# cvû^¾ÿ_²>vØ¾ÓAþøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþ?ÿþ8þ?ÿüÇãÀÿÿÿÿÿÿÿÇÿü?üÇñÿþ?8ñÇ¶ßÿwÍy
# ¹$ÿÿÿÿÿÿÿðqÀpÿÿÿàÀÇñøøÿÿàÿÿÿÿÿà?üàø?ÿÿÿÿÿÿÿÿÿÿÿð?üÿÿÿÿã8ÿ8¶raíÎû¬czªôsÏ=Î
# ¹ýµx;×w»í¯û:»Iqúñ?ûdîUÿ0
# Ê·ü|ÿÿÿÿÿÿÿÿÿÿÿñÀüãÀÿÿøøÿàÿàÿÿÿÿÿþãÀãÿà8àqÀ?~?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÇãð?áZ
# ß}ºUWÑ·xkêôÎ2¹Üø´^7Ý®ØÏÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀüÿà~à8üÀøüÀð?ÿÀã8ÿÇàqÀÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ~8ÿÿÿÿÿÇ~ãÿÿÿþüqÀãÿÿÿÿÿÿÿñ¸ÜoÏÿ 4):Ðí~½äg`ô·ð?ü÷sûøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀ8ãqÀøp8ÿþàøÿàqÇà~?ààÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ?ÿÿÀ?àp?ÿÿÿÿÿÀ?ÿÿÇãñÀ~þ?ÿÿÀ?þ?ÿÿÿÿÿÿÿøãÿ¶Ú2ÛXÕöúG¶ØBw¶ü£sÇÿñ÷ÅÓUÿìüÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøãÿüñøãð8ÿÿqÀàp?ãþÀÿðpà~8?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀÿÿà~8ÿÿàÿÿÿÿàÇqÿÿÿÿãþÿÿÿÿÿÿÿüýöÜoñ@ia]6?Æ*×«eMÉÇàøá¤ìßíÒð8ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿüÇÿÿÇüp?p~8ãð?àÀøÿÿãðñøãÇÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿàÿÿðÇüÿÿÿÿÿðÿÿÿÀüÿ?ÿÿÿÿÀÿüÿÿÿÿÿðâfãmßøµ²î<ÉYûÒ\áÝÒÙ$üÇ¡ÉL¯Çæüÿÿÿÿÿÿÿÿÿÿÿÿÿÿðãøðüqÿüøþ?ü~8?ÿÀü?üÿÿÿÿøüÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿðÿñÇÿÿÿÿÿøÿÿÿðqÇÿÿøñÀðÿÿÿÿÿÿà}#læ`)¹²2[zß{köÔ®ö³nÀãþfR
# ¦ç3ÿãð???üÿøÿþÿøÿþÿðÀÿþÿÿqÇÿÿÀÿÀã8ÀÿÇÇüÿàøqøÿ?~8ãþ±ö«¶É|Ù^èýÎãÿøepØ½PãÀp?Àà~à?ÿÿàÿ?ÿÿàøÿð?ÿÿÀÿ8ãþ?ñÿþ?üÀããþ?ÿÿÿÿÿÿÿ?Àqÿp?ÇàqÇqã°Ûd¶@ï÷_øqÀJß|þ«øñÇ8ÀàãÿÀÿÀÀÿÀÿÇÿð8ÿp?àÀqÿ~à8þppqÿÿÿÿÿÿÿð?üÀÿñÀü8?üï,u²[6¢_äó?ü?ºgcÚ?qÀ8àp8ø?à?üü?à?àÿüøü?ÿð?à8àøüÿãÇàøüp?8ÿÿÿÿÿÿþðÿñÇàpÿÿÿøøãðÇRë$¶ÚÁ6p@?þÿ=Ww2dRãÀqÇqøøàøÿÿÿÀøøÀpþ?üÀàøðÿøÿÀÿãþÿÿÿÿÿÿÿÿÿÿÿøÿñÀÀøÿþàÿøü?ÿÿýlMdúÞÿû?U~ÀãÀ¿¥AvoÈËãÿ?ãÿÿãñÇþÿÿÿÿüÿðÿüà?üp?Çüø8þãø8ÿÀÿÿÿÿÿÿÿÿÿÿÿüÀà?à?ÿÿÀðÿÿÿüp8ãþñÿü©pjKõ×ÿçà5«øãÀý_ÑÔ'SÑÿñÿ~ãÿÿøqÇÿøÿÿÿÿÀÿÿøÿÀÿÀüqÿþüÇÿÇþÿàÿÿÿÿÿÿÿÿÿÿÿÿþ?àðÿÿàÇüqÿüãÀqÇàKò\¾ÿ<þ4ùg¶ÿã8oí@Òw¯ÇñÀÇqÇ~?üÿÿÿÿàÿþ?üÿàÿàüqÿþãøÿðãÿøü?ÿþÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿãÿÿü~?ÿÿÿÿÿÿÿðÿ?ðü?9µ}rs k²1*cøþ´ÇñIWÿàÿÿÿÿÿÿÿÿÿÿðøÿþp?ð?ÿÿÿ?pÿøà?ÿÿÿÿÀÿÿÿÿÿÿÿÿÿÿÿÿü?ÿÿÿÿÿÿÿÿÿ~ÿàp~?ÿÿÿÿþÿø?ÇÀàØåZÀBíÙ?tcÀZ:ÛbhÿûÀÿÿÿþÿÿÿÿÿÿø?ÿÿà8øÿÿÀÿÀ8ü~8ÿð8ü8~ÿÿÿ?ÀãÿÿÿÿÀÿÀÿà?ÿÿÿã8ü~Îò¢ªÎáÎú}"NàãÇà8Tq5ÿãþÿÀÿÀÿÿÿÀ?ÿÿÇÿðÿÀÿÀÀÿàÀàÀÇÿÿÀ?ÿà?ÿÿÿÀàpøÿÇÿÿÿÿÿÿÿÿÿÿÿñÿøÿÿøþß¶Ú÷oøÀã8
# ÇhGÀÛùÃùÛüáÿÀÿÀÿísPÄäÉÀ8ÿÿøãðÿÿÿÿÿøãÿøÿøð8ÿÿÿÀÿÇþãÿÇÀü~8ÿøÿøøÿøÿÇüÿÿÿÿÿøÿþ8üÇÿñÿð?qÿüÿÿÿøÿð8ãÿÿÿÀÿWhA¥\áDññ·ÿÿ8p8ºT0ñíÏqÿü8à8üÿÿüqÇüÿqÿüÿüøÀÀÿþpp8üÿãÿÀñøþÇüÿüü?ü?ÿÿÀÿÀÀÿð?ã8~øñÇÿÿÿüÿÿÇp?ÀqÀãýx`Ý8â
# !g{øÜ;ãÿÿü?àñøãÿÿÿüÿãÿÿÿøÿÇàøÇÿÿãðü~8qÿ8ÿÿüÀà~8à?ÿ8ÿÿÀÿøÿÿüÿÿÿÀqÿÇàÀøÿð?ãÿÿÿÿÿÿÿÇðüqÀàøAÛrýsþ§L³q7f?àoºuvZMé«oÇÿÿüÿÿþøãñÿÿòÆà7ÝLx4HÜaÉñ@lñÀãð?~8ÿþÿÿÿÇñøÿñøÿøãÿããÿÿðàÀàqÇÿ~ðüÿøÀÿÿà?üÿÿþÿñÿàüü~8àqøàÿÿÿÿÿÿÿÿþ8üÿñÇ É~ é¤î{n'Ãà?ÇtÛeÆÑß¹
# WÿÿþÿÀàqÿüÀ>p­%·e°Kwó°vÉÿãñÀüqÀÿü~8ãÿÿÿÿÀÿÿøð?ñÿþãþ?ã?ÿÿÿøü~?ÿþ?ü?ÿÿÿÿþÿÿÿàÿÀþ8ÿð?þãþ?ÿÿÿÿÿÿÿÿÿÿÀüø~ÿp?o#Otxÿ÷=´åXÿÇÿo©²Gí§xÉÿàÇÇ~þEÏ-·ø0YÄøxð?àðÇü?ÿÿÀ?Ç~8üøøÿÿÿqøqøÿÿÿ8à?~ÿÿÀÿÿÀ~ÿÿàÿÿþãÇÇÀÿðøÿÿÿÿÿÿÿÿÿÿøãÿàÿ8üÎÂ<H`Ù~<O'E$ÒPMe®J¤ÿð8ãÇÀôwgr«wî6üÿcF?pñÀpÀ8ð8ÿñÀÿðp?ÿøqÿÀüÇüÿü?ÀÿÿÿÿÀüÇüqÿüqÿü?à8ÀÿÿÿÿÀãÿÿà8ãð8Çü?ÿÿÿÿÿÿÿÿÿÇÿøÀ8ÀÿãÿÛ~FßbêÛÐcxÅù?¹Þ¿h<
# üÆEl#âJ¬w¡fÏã¹~
# ÂsÃqÉK.3«¨¯8l ?ðÿÿãþ8üÇñÇãþü8ãñøÿàÿà?ãÿÿþüÿøüÿÿÿÇøÿøøþ~ÿà~øÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøøã?üÿÿþ8ÿÀÿù$r7$I¤·p~ØÎ5½ÐÿçO!2ÝÀ~ü
# q¸=Êÿþð8þÿãÀàqÇøÿþ8øþð?ÿàÿàÇpüqøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÇÿñø~àÇãþüÀü?ÇÛ
# ãÿñÀãþ?ÀþÀüÀÿðãøÇÿÿà?ÿ?üþÿÇÿ?ÿøÿð?ÿÿÀÿ8ð??ãð8àqÀðüÿà~?ã8#6Üíó¢>m¶ÉfN	#pt $âcÿùrv ,pÀà?~ñ8É{áßû©À®ñðìÿ·3Wbxö4£î6GÃqø?ÀãþñÿààÇðqÿÿÿÀÿøÿÀÿàÿqÀàÿñÀþàø?üqÇàpÀã8ÿÀãÀÇãÿÿøðqÀnFíÐÖÝ#6¯'FäC9}ý|>'º>Âì@ @r£þàÿÿñÇ³Ì£É´MCO[Ïlá¬LÁè(eIAÃr
# [óËùþ1ÿþ8þþüÀðÇÿà8?ÿÿðÿøqÿàÀ~üàqÀ~8ãñÇãàÀüÇp?øpÿü8àüÿÇÿà8ØíÈgþk¶ãe[´Þ%ntÃ5fOà^½ÉqNøqÿH4[Äæ	ôÈ?6&°óSñÞQ)'wYÀ[n0;ÀÿÀ?üqÀþÀÿÇÿøøÿÿÿÿÿÿÿüÿøñøÿñÿp?Çàÿüÿþüÿ?ñÿãÿøàüÀà~8ÿÛy `ÓÐN§ô=²6_ÔRéþ;û
# ¤g$vÓ¥ÿÀÀÄêÜ\  ^}6E$VÎ_á·ÃÛyÔuÈäüÛð8À~?þÀðüqÿü?ÿÀ?ÿðüÿÿÿÿÿÿüÿãþþ8ÿ8øüÇ?ÿÿü?~üÿ?ÇÀp8àø?ñÇüÅÊÇ(6ÓÂþÛøm´ª'ì_²¦¬øuÊ­¤ö<)#~Àãþøü~?ÿñ´`7÷.MÀäðßqðl=´sá8q%jcöÛÌøqçíÉ?ÿþ8ãñÇãð8~ø~üÿÀàÿÿÀÿÿÿÿÿÿÿÿÿ?à?ãÇÇ~øñÿüÿÿþÿÿøãñÇÀqÿÀqøñÀüøãòHä×ôªÈ­¼7µ+¿ðL«|I¸ö:íÿ8ºàqøÿÀÿÿÿÿÿÿü?ÿm¿$ÎèÈü'º¿D¸
# 5$O¹#r~ÿþùLrÀÿüÿøðÀãÿÀñÿÿÿÿÿÿÿÿÿÿÀãñøÿþüÿÿÿÿðÿüøüÀÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ?ñø~~8àqøÀ~äòv`	9$ÿ$¾äwÆ'A!Î½ÄæÅ
# xÜáÇÿàÿÿÿÿÿþ¶ßñûq­¦É$tChFH
# Î'o×ø ×oüÿø~ÿÉ7äÃapóðãuí/ÁÃ	UMÆöÕÿ?àÇ-mÉÿÿøãÿü~8ãøÿðà~pÿÿÿÿÿÿÿÿþ?ãð?ÿàøüÿÿÿÿÿÿ8ðÿÿþÿÿþÿÿÿÿÿÿÿÿþ8ÿøÿàÿÇààäîÜQ©ÿ$nIq·ÿ
# &FÀÿÀÿÿà#îwäÏ1ÌÆÇ_nvò6i[jM·ÿàÿÿÿ&ÐxåSçþðàÿüÇpÿàøñÿüÿàÿÿã8Àøÿÿà~àp8ÿþ?à?àøàÿøÿñÿÿÿÿÿÿÿãð
# Ûm¶Ô@{JAËÃsÿÿÿøüÿÿÿðÿÿð8ðF±ØúþGpÐiÉ=ùRIT£ãÛm¶ÛmøÛÿûG	Æà!²A¿ÿàüqÇàqøãðüpÀü?àÇüÿàpÿÿÿðÿñÿàÿÿàÿ?ÿÿÿÿÿÿÿÿÿÿÿðÇàÀàp?ñÇñÃcøÏ{¨ÜFÂÛm¶ÛrKm¶ÛjI 	=¨æ9ÿÿþ?à?üÿÿøÿÿÿ~ÌA?bþø1ÌÖ¢_$Ùýµ$²Aûm¶Ûm¶ßüýo¡qã'ä°?ÿ~p?àqøüÿø8ÿÿÿÿÿÿøü8ÿÿÿü~88ÿÿÿÿÿÿÿÿÿÿÿøðÀqøÇ8ÇÿsäíøìKäølI#nI%¶Ûmµ$ÓôóD\ÿÿÿÿþ8ãÿøÿÿüÿÿüÀâ>ÐvÒÙAÃîw
# Éý¶þM¤I[m¶Oü[oá? ¢ðXàFãq°?ãÿñÀÇqÿÿþp?ààÿÿÿàÿÿÿÿÀÿÿÀÿÿÿÿp?à~ãðãÿÿÀÌÜ?EUp?
#  |§Îp?ã?ÿÿÀÇëüâPïjZÛ$m¹$I$­¶Û'KmÿÿÇ`ñ÷:Lù$ÙÌà?Ç~?ñÀÿð8ÿÿÀ?ÿ?àÿÿãþÿþ?ÿþ?üÀ?ÿÿÀ8ãÀÿÿ?øp$
# v¡ÿµ&äI$¶ÛmI$pø<Ã}¿Â),'¿ivo#àÀ??þ?ÿÿÿÇp88ñÿÿÿðÿÿñÀü?àÿÿñø~~88ÿÇq£¼h`Gûk. øÿð¶«m¶ÛmI$©Zÿþ[6
# ñá¥Ä¶@V¤Ü$I$I$Ûþ8ö÷o~·8è´W~vÃøà?àp?àþÿÿøü~øÿÿÿÿÿÿÿÿÿð?àÿÿàãð8ãÿÇ?àÇãð?Çðü~íñæàÕÎðÛAgé#u[jI$I$U+R ÿÀuÚûs8àÿÿð?ø:Ï*á[ +RnDI$I$m°8ü
# REÝ¶ÿàÿÌgwì$¶©*I$à+øqÀ5[Hvßýþçdîa*¹öp8Àÿðþÿp?Àüøÿÿÿÿÿ~?ñøÿÿÿÿÿÿàqÇøàÀÿþüû9±ÏÏØûÿþHØI%lª¤ª©Éø½ÊDí­H0Àÿeêùºq~ªÊò í´ÿÿÿÿÿÿÔI$Iú¤ßà*­¶¶àÿÿ¹ÿÁc¤Î8Ààqø?üÀqÀÿà?ÿÿÿÿÿÿÿþøÿÿÿÿÿÿñøàqøñÀàÿàÀ;:Ä¢6$m¤¶ÛUJÒÿà@]¶ÖÛÿÿù$qú²ÖÜQ?#
# Ôª¶ÚÛøühÈåÆÿÿÇàpøãÀððãðÿÿÿÿàÿà?ÿÿÿÿÿÿøðü~ÀüÇp?ðð8ÿñ"â¶ãñ'ÿÿü¶JÛmVØ³nqZ|GÿòHÙ$01ìé1§YÆÃÆÿþ­ßÍÈO
# ZÅóíwí?ÿ?ÿÿÀÿæÜÒ9þ9õ°U@I$I$Ä¯íI+dlpÿÿÿÿàsægÀÇ8~ÿ8ÇÿÀp?ÿÿÿÿÿÿÿÿÿÿÿø8àÀàÀü?àqÇð7ÿÀWùÃÿð?6íI$­©$Å _¹DàúIZÕ[â`=O´»ò@ÿÀ³m¶ãð/!$À 	$U$«Á(ö¤±¶8?ÿÿÿÉÇ·K¿þ?ÿñøãþ?ÇüqÇà8ÿàqøÿÿÿÿÿÿÿÿÿÿÿÿàøø~?ãà?ð~düáÿøÉv«jVÔLhØ9àEO;¥Ù=2]ù ÿàvÙ¼ÿqgDMðI+jµ"Ep6RJÖÛøÿÿÎdkQÇþ8àqÿøüpÿÿà8ãþÿÇüÿÿÿÿÿÿÿÿÿÿÿð?ÿÿÇÀ??ãþ8àqÀqü
# ÇþNÇàäº¶«jI)ÀWý¼}Pý·$ì>¿×Óó÷Né.üÿðÿÿø¯fÜ|<®ØpI$¶Ûi=Hã;©%krqÿÿÁ¨ÇüqÿÀøãÿÀøøqÇàÿÿÿüøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿøÿñÇàqÀÿ8ñÿþà8]ÓÐOÿçÿòFÝV«mµ$:9À7/qÇÈúH@Áë&AÍ<~HÿøÿÿüÿlÿúxÇ5í$IZª¨ïduÚÔµÉ8ÿÿø`ÄÜ£Oðàp?ÿà8ÿÿÿãÿÿüøãþ?ÿÿÿþ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ?üqÿã8øãÿøüÿ¯¬'ÿóÀÿù#nª¶ÚKù]ÁÎH?8°*Ó­[=ÆÜÖK¿$ÿü'ö·øüwð³¿ð%U¶YþÜGêIZä?übeBþ?ÿð8à~?àþÿþÿÇÿÿÿÿÿøüÿÿÿÿÿÿÿÿÿÿÿÿÿüÿÀàÀ?àÿñÿ#¨ÿÉøü¶ÝI[mI$¼«Ñäã#~?ù³ü:Db^mÇ5ßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÛoÿÿÿÿ;üïíÅÝcrX´òHÙ`;äé+[OÿÿÿÿÿðöÐ¶§<~àÀÇ?Àÿ8qÿàøüÀüpÿÿÿÿÿÿþÿÿ´±Ñ¿ÿÀpüqÀ8øøÿøw¹·tÿÿÿÿIÚµñÛm¶ÛÚK6ÀçGîÿðÛßÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿ~þ´ÝçUÉ:K¾*ÇSÉ$dñz²I'ÿÿÿÿÿøû@K»å±ÀàÇÇãÀÀÿ?ãÿÀãÿÿþãøüøñÀÿÿÿÿÿÿÿ<ÉÅ»uëT8p?ÿðã?üÇüp8ü~ãí]º@ÿÿüÉm¶ÚøNm$m%¿Û«´3qÀÿÿÿÿÿÿÿÿÿÿÿ?ÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿÀàrämà
# `U¼¯äÀÀã8ãÈã±7R% I$I$­©_À¶cÙ	m¶ÿþ@8kÆòí¬ÏN
# sXþ$¶Ûÿÿí¶Ù 7ÁÒ6ÿÚ©$I$@6_Ð À8ãð8øpÀãðàÿàqÇãøÿÿÿÿÿÿÿÿÿÿÿÿÿÿÿþÚÄ5¤æ?Ç@@ÿÀà~Çÿøü$i\VíoþÛm¶Ûm¶¥oÿÿ$ý@d¶Û{ù Q$,Øy0`àÀðÇà"q>lI$ÛnÖÛlàoÿÿ©+m¶Ûm¶Ðm.ãð?qÀp?þãðà8ãÿøãÿÿÿÿÿÿÿÿÿðÿÿÿÿÿðÿÇÿøÿÿÿÿÿÿÿÿÿÿôE]DÚHm¿æ+ù  ÿðð?ÿÀmÉñÛm·ÿÿÿÿÿÿôüäg
# ¦Ûo¶Ç¥qËâl)ÀîÉpqüq}BÿÀØvÛÀñÿà~ÿð?øÿãÿÇÿ«-:ÚÕZ¯Ík|K|Íøà$ÿÿà~øã?ò6ãü/Ã{è¢õè@wqD"óNØ°x±×'àÀÿÿÿÿàÿà?ÿðl
# ·mm¶Ý ÿÿÀ8ÿàpñHÜ¹/vÿÿìÿàÇÿÿ
